# %% [markdown]
# # PHYSICS 1:  PYTHON DATA ANALYSIS OF THE CAVENDISH EXPERIMENT
# <p style="color: blue">Inspired by and containing material from ["The Cavendish Experiment"](https://nbviewer.jupyter.org/urls/www.numfys.net/media/notebooks/cavendish.ipynb) by Jonas Tjemsland and Jon Andreas Støvneng</p>

# %% [markdown]
# ### Student ID:

# %% [markdown]
# ## Pre-Lab Tutorial Questions

# %% [markdown]
# <p style="color: blue">Newton's Law of Universal Gravitation relates the magnitude of the attractive force, $F$, between two point masses, $m_1$ and $m_2$, to the inverse square of their separation, $r$,</p>
#
# <p style="color: blue"><a name="eq:grav">*Equation 1:*</a>  Newton's Law of Universal Graviation
# \begin{equation}
#   F = G \frac{m_1 m_2}{r^2},
# \end{equation}</p>
#
# <p style="color: blue">where $G$ is the gravitational constant.
# It can be shown that this equation also holds for spherical masses of uniform density if $r$ is the distance between their centers.</p>

# %% [markdown]
# <p style="color: blue">In 1798, Henry Cavendish published the first laboratory-based direct measurement of $G$ (Cavendish, H., _"XXI. Experiments to determine the density of the earth"_, **Phil. Trans. R. Soc.**, vol. 88, p. 469, [doi:10.1098/rstl.1798.0022](https://doi.org/10.1098/rstl.1798.0022)).
# In the prelab, we will describe the torsion pendulum, the heart of Cavendish's experiment, and derive its physics.
# In the lab, we will estimate $G$ using computerized analysis on data collected by students who reproduced the experiment in 2014 at the Norwegian University of Science and Technology (NTNU).</p>

# %% [markdown]
# <p style="color: blue"><a name="Prelab1">** Pre-lab 1.**</a>  If $G = 6.67 \times 10^{-11} \mathrm{N}\,\mathrm{m}^2\,\mathrm{kg}^{-2}$, what is the gravitational force between a lead sphere of $1.5\,\mathrm{kg}$ and a smaller lead sphere of $10\,\mathrm{g}$ mass whose centers are separated by $5\,\mathrm{cm}$?</p>

# %% [markdown]
# <a name="Fig1"></a>
# ![rstl.1798.0022-Fig1.jpg](attachment:rstl.1798.0022-Fig1.jpg)
#
# <p style="text-align: center; color: blue">Figure 1:  Illustration of Cavendish's experimental apparatus, **Phil. Trans. R. Soc.**, vol. 88, p. 526, [doi:10.1098/rstl.1798.0022](https://doi.org/10.1098/rstl.1798.0022).

# %% [markdown]
# <p style="color: blue">The experimental apparatus is a simple torsion pendulum, similar to the one depicted in [Fig. 1](#Fig1).
# Instead of swinging in a vertical plane, a torsion pendulum twists in a horizontal plane.
# A horizontal rod is suspended from its center by a wire (in [Fig. 1](#Fig1), $n$, $h$, and $m$ are points on the rod).
# Twisting the rod in the horizontal plane away from its rest position by a small angle $\theta$ results in a counteracting torque from the wire, $\tau$, given by</p>
#
# <p style="color: blue"><a name="eq:thook">*Equation 2:*</a>  Torque of a torsion wire
# \begin{equation}
#   \tau = -\kappa\,\theta,
# \end{equation}</p>
#
# <p style="color: blue">where $\kappa$ is a constant of the wire called the torsion constant.
# Note that this has the same mathematical form as Hooke's Law for a spring,</p>
#
# <p style="color: blue"><a name="eq:hooke">*Equation 3:*</a>  Hooke's Law
# \begin{equation}
#   F = -k\,x,
# \end{equation}</p>
#
# <p style="color: blue">from the Simple Harmonic Motion (SHM) laboratory.
# The analogy with spring motion is excellent, and the same mathematics describe the twisting of a torsion pendulum and the the translation of a mass on a spring.</p>

# %% [markdown]
# <a name="Fig2"></a>
# ![cavendish_basic.png](attachment:cavendish_basic.png)
#
# <p style="text-align: center; color: blue">Figure 2:  Top view of a torsion pendulum looking downward.
# Each arm of the pendulum has a length $r$ and a lead sphere of mass $m$ attached to its end.
# Two large lead spheres of mass $M$ are placed in symmetric positions as indicated with their centers in the same horizontal plane as masses $m$.</p>

# %% [markdown]
# <p style="color: blue"><a name="Prelab2">**Pre-lab 2.**</a> When a force $\vec{F}$ is applied to an object that rotates about a fixed point at a position $\vec{r}$ relative to the fixed point, the torque produced by the force is</p>
#
# <p style="color: blue"><a name="eq:torque">*Equation 4:*</a>  Definition of torque
# \begin{equation}
#   \vec{\tau} = \vec{r} \times \vec{F}.
# \end{equation}</p>
#
# <p style="color: blue">After the two large masses $M$ are introduced as indicated in [Fig. 2](#Fig2), the pendulum is allowed to come into equilibrium wherin the torque from the wire torsion balances the torque from the gravitational attraction of the lead spheres.
# If $m = 10\,\mathrm{g}$, $M = 1.5\,\mathrm{kg}$, and $b = 5\,\mathrm{cm}$ as in [Pre-lab 1](#Prelab1), and if the torsion constant of the wire is $\kappa = 10^{-6}\,\mathrm{N}\,\mathrm{m}\,\mathrm{rad}^{-1}$ and the length of the arms of the pendulum is $r = 5\,\mathrm{cm}$, what is the angle $\theta_1$ between the new equilibrium and the untwisted state of the pendulum?
# Assume that the angle is small enough so that $\vec{F}$ and $\vec{r}$ are approximately perpindicular.</p>

# %% [markdown]
# <p style="color: blue">Continuing the analogy with spring motion, Newton's Second Law for rotational motion relates the applied torque to angular acceleration, $\alpha$,</p>
#
# <p style="color: blue"><a name="eq:newt2">*Equation 5:*</a>  Newton's Second Law for rotational motion
# \begin{equation}
#   \tau = I \frac{\mathrm{d}^2\theta}{\mathrm{d}t^2} \equiv I \alpha,
# \end{equation}</p>
#
# <p style="color: blue">where $I$ is the moment of inertia, which plays a role analogous to the mass in a spring system.
# Assuming that the rod of the torsion pendulum is massless, for two equal masses a distance $r$ from the center of rotation,</p>
#
# <p style="color: blue"><a name="eq:moment">*Equation 6:*</a>  Moment of inertia for torsion pendulum
# \begin{equation}
#   I = 2\,m\,r^2.
# \end{equation}</p>
#
# <p style="color: blue">Thus, the equation of motion for a torsion pendulum oscillating around its equilibrium is mathematically identical to the equation of motion for a spring,</p>
#
# <p style="color: blue"><a name="eq:shm">*Equation 7:*</a>  SHM for rotational motion
# \begin{equation}
#   I \frac{\mathrm{d}^2\theta}{\mathrm{d}t^2} + \kappa\,\theta = 0,
# \end{equation}</p>
#
# <p style="color: blue">which has the familiar solutions of simple harmonic motion,</p>
#
# <p style="color: blue"><a name="eq:shmsolve">*Equation 8:*</a>  Solution to SHM for rotational motion
# \begin{equation}
#   \theta(t) = \Theta \sin{(\omega\,t + \phi)},
# \end{equation}</p>
#
# <p style="color: blue">where $\Theta$ is the angular amplitude of the oscillation, $\omega \equiv \sqrt{\kappa/I}$ is the oscillation frequency, and $\phi$ is a constant phase.</p>

# %% [markdown]
# <p style="color: blue"><a name="Prelab3">**Pre-lab 3.**</a> What is the period, $T \equiv \frac{2 \pi}{\omega}$, of the torsion pendulum described in [Pre-lab 2](#Prelab2)?</p>

# %% [markdown]
# <p style="color: blue">Torsion pendulums can be extremely sensitive, as they must be to be affected by the gravity of an object that can fit in a lab.
# The apparatus used to collect the data that we will be analyzing is sensitive enough that air resistance has an observable effect on the pendulum's oscillation.
# The force of air resistance on a small moving sphere, such as the small masses $m$ at the ends of the pendulum, is approximately proportional to the velocity $\vec{v}$ of the sphere via Stokes' Law,</p>
#
# <p style="color: blue"><a name="eq:stokes">*Equation 9:*</a>  Stokes' Law
# \begin{equation}
#   \vec{F}_{\mathrm{drag}} = -6\pi\,R\,\eta\,\vec{v},
# \end{equation}</p>
#
# <p style="color: blue">where $R$ is the radius of the sphere and $\eta$ is a constant of the medium called the dynamic viscosity.</p>

# %% [markdown]
# <p style="color: blue"><a name="Prelab4">**Pre-lab 4.**</a> Show that the torque due to air resistance can be expressed as</p>
#
# <p style="color: blue"><a name="eq:drag">*Equation 10:*</a>  Torque due to drag
# \begin{equation}
#   \tau_{\mathrm{drag}} = -N \frac{\mathrm{d}\theta}{\mathrm{d}t},
# \end{equation}</p>
#
# <p style="color: blue">where $N$ is a constant.</p>

# %% [markdown]
# <p style="color: blue">Adding this air resistance term to the equation of motion gives the differential equation of a damped harmonic oscillator,</p>
#
# <p style="color: blue"><a name="eq:dhm">*Equation 11:*</a>  Rotational damped harmonic oscillator
# \begin{equation}
#   I \frac{\mathrm{d}^2\theta}{\mathrm{d}t^2} + N \frac{\mathrm{d}\theta}{\mathrm{d}t} + \kappa\,\theta = 0,
# \end{equation}</p>
#
# <p style="color: blue">which, for an underdamped harmonic oscillator, has solutions</p>
#
# <p style="color: blue"><a name="dhmsolve">*Equation 12:*</a> Solutions to the damped harmonic oscillator equation
# \begin{equation}
#   \theta(t) = \Theta_0 e^{-a t} \sin{(\omega\,t + \phi)},
# \end{equation}</p>
#
# <p style="color: blue">where $\Theta_0$ is the initial amplitude of oscillation, $a \equiv N / 2 I$, and $\omega \equiv \sqrt{\omega_0^2 - a^2}$ where $\omega_0 = \sqrt{\kappa / I}$ is the frequency of the undamped harmonic oscillator.</p>

# %% [markdown]
# ## Aims

# %% [markdown]
# - <div style="color: blue">To study Henry Cavendish's lab-based measurement of the gravitational constant.</div>
#
#
# - <div style="color: blue">To reinforce the data handling and plotting skills introduced in the previous lab.</div>
#
#
# - <div style="color: red">*Key focus:  to perform a fit of a non-linear model to a data set.*</div>

# %% [markdown]
# ## Part 1:  A first look at the data

# %% [markdown]
# <p style="color: blue">The oscillations of the pendulum used in the NTNU experiment are very small, so the angulur displacement of the pendulum is not measured directly.
# In order to amplify the motion, a laser beam is bounced off a small planar mirror that is affixed to the pendulum and projected onto a screen as shown in [Fig. 3](#Fig3).</p>

# %% [markdown]
# <a name="Fig3"></a>
# ![cavendish_setup_right.png](attachment:cavendish_setup_right.png)
#
# <p style="text-align: center; color: blue">Figure 3:  Top-down view of the experimental setup.  A laser beam (7) is reflected from a mirror at the pendulum's center of rotation to a screen (6) located a distance $L$ from the pendulum.
# Image source:  ["The Cavendish Experiment"](https://nbviewer.jupyter.org/urls/www.numfys.net/media/notebooks/cavendish.ipynb).</p>

# %% [markdown]
# <p style="color: blue">The position of the laser beam on the screen, $S$, is measured with a ruler and recorded.
# For $S \ll L$, displacements of the measured position $S$ are approximately linearly related to the angle of the pendulum,</p>
#
# <p style="color: blue"><a name="eq:stan">*Equation 13:*</a>  Geometric approximation $S(\theta)$
# \begin{align}
#   \frac{S}{L} &= \tan(2\theta) \approx 2\theta,\\
#   S &= 2 L\,\theta.
# \end{align}</p>

# %% [markdown]
# <p style="color: blue">The pendulum is very slow to come into equilibrium and easily disturbed from equilibrium.
# Rather than waiting until the pendulum was stationary in order to measure the deflection caused by the gravitational attraction, the experimenters recorded the osciallations of the pendulum about its equilibrium position in order to determine that equilibrium position.</p>

# %% [markdown]
# ### <a name="P1.1">1.1:</a>  Equation of motion

# %% [markdown]
# <p style="color: blue">Show that motion of the laser spot on the screen has the form</p>
#
# <p style="color: blue"><a name="eq:sdhm">*Equation 14:*</a>  $S(t)$
# \begin{equation}
#   S(t) = S_i + A_0\,e^{-a t} \sin{(\omega\,t + \phi)},
# \end{equation}</p>
#
# <p style="color: blue">where $S_i$ is the beam spot at the pendulum's equilibrium postion and $A_0$ is the initial amplitude of laser spot on the screen.</p>

# %% [markdown]
# <a name="Fig4"></a>
# ![cavendish_setup_left.png](attachment:cavendish_setup_left.png)
#
# <p style="text-align: center; color: blue">Figure 4:  Top-down view of the experimental setup in the region around the torsion pendulum.
# Components shown are (1) the torsion wire and center of rotation, (2) the mirror, (3) the large lead balls, (4) the small lead balls attached to the arms of the torsion pendulum, and (5) the incoming laser beam.
# As shown, two experimental conditions were tested, one in which the large lead balls are in the positions indicated by the solid-line circles, and one in which they are in the positions indicated by the dashed-line circles.
# Image source:  ["The Cavendish Experiment"](https://nbviewer.jupyter.org/urls/www.numfys.net/media/notebooks/cavendish.ipynb).
# </p>

# %% [markdown]
# ### <a name="P1.2">1.2:</a>  Import the data
#
# <p style="color: blue">As shown in [Figure 4](#Fig4), data sets were collected with the large masses in two different but symmetric configurations.
# Copies of these data sets can be found in the files `S1data.txt` and `S2data.txt` as white-space separated columns of values.
# The first two columns are the time of the data points in minutes and seconds, *mm:ss* = col1:col2.
# The third column is the position $S$ of the beam spot in mm.</p>
#
# <p style="color: blue">Load the data sets from the files (remember `np.loadtxt` from the previous exercise).
# For each data set, create two arrays, one with the time values in seconds, the other with the $S$ values in m.</p>

# %%
## Always remember that packages must be imported before use
import numpy as np

# %% [markdown]
# ### <a name="P1.3">1.3:</a> Plot
#
# <p style="color: blue">Make a scatter plot of $S$ vs. $t$.
# Plot both sets of data on the same plot.</p>

# %%
## Make matplotlib.pyplot available and set Jupyter to show you the plots in the ouptut
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 2:  Fitting the data

# %% [markdown]
# <p style="color: blue">The functional form of [Eq. 14](#eq:sdhm) derived in [Part 1.1](#P1.1) is much more complicated than a polynomial.
# In order to fit this function to the data, we will define our own python function to do the calculation.
# If you are new to python functions, the cell below defines a short function for the motion of a simple harmonic osciallator without the damping term:</p>

# %%
def shmmodel(t, S0, A0, omega, phi):
    """Compute the position of a SHM at time t."""
    return S0 + A0 * np.sin(omega * t + phi)

# %%
## shmmodel can now be used to calculate S values for given t values
S0 = 0.4
A0 = 0.025
omega = 2 * np.pi / 1250.
phi = np.pi / 4

S = shmmodel(0.3, S0, A0, omega, phig)
print( "S = ", S, " at t = ", 0.3, " s")

# %% [markdown]
# <p style="color: blue">Some comments about the form of `shmmodel`:</p>
# 1. <div style="color: blue">The fitting procedure expects the independent variable, $t$ in this case, to be the first argument of the function,</div>
#
# 2. <div style="color: blue">Parameters of the model that are to be adjusted by the fitting procedure to the best representation of the data should be arguments to the function,</div>
#
# 3. <div style="color: blue">By using the NumPy version of the `sin` function, `shmmodel` is compatible with `np.array`s as input for $t$ and can be used, for example, in Matplotlib plotting (see below).</div>

# %%
## Illustration of plotting a user-defined function
S0guess = 0.4
A0guess = 0.025
omegaguess = 2 * np.pi / 1250.
phiguess = np.pi / 4

ts = np.linspace(0, 1750, 256)
plt.plot(ts, shmmodel(ts, S0guess, A0guess, omegaguess, phiguess), color='red')
plt.show()

# %% [markdown]
# ### <a name="P2.1">2.1:</a>  Model function
#
# <p style="color: blue">Define a python function for the motion of a damped harmonic oscillator.
# Remember to use the NumPy versions of any functions in which the time appears.
# Make a plot with the function that you have defined.
# If you need to know which functions (like `sin` in the example) already have defined NumPy versions, it may be helpful to use python's built-in `dir` function, which returns a list of all of the components of a module.</p>

# %%
dir(np)

# %% [markdown]
# ### <a name="P2.2">2.2:</a>  Curve fitting
#
# <p style="color: blue">The SciPy package expands on the utilities of the NumPy package to do more complex tasks, such as non-linear curve fitting.
# We will be use the `curve_fit` utility in the `scipy.optimize` module to fit our damped harmoic oscillator model to the data.</p>

# %%
## Make scipy.optimize.curve_fit available to Jupyter
from scipy.optimize import curve_fit

# %% [markdown]
# <p style="color: blue">Remember that you can use `help` on `curve_fit` for more details about it.</p>
#
# <p style="color: blue">The `curve_fit` function will take as arguments the model that is supposed to define their relation (the name of your damped harmonic oscillator function), the array of values for your independent variable ($t$), and the array for the corresponding dependent variable ($S$).
# It will find the values for the model parameters (_i.e._, $S_i$, $A_0$, $a$, $\omega$, and $\phi$) that minimize the $\chi^2$ between the computed model values and the measured values of $S$.
# It will also compute a covariance matrix for the best-fit model parameters.</p>
#
# <p style="color: blue">Note that one could define their own linear or polynomial function and repeat the fits in the previous Python Lab with `curve_fit` instead of `np.polyfit`.
# There are almost always several ways to accomplish the same task in python.</p>

# %% [markdown]
# <p style="color: blue">One of the new features that you will need to use is an 'initial guess' for the model parameters (the `p0` argument of `curve_fit`).
# If the initial guess parameters define a model function that is too far away from the data, the fitting procedure may fail.
# It does not need to be precise, but you need to start the fit procedure in the right 'ball park'.
# The initial guess for the parameters should be a python list of values in the same order as the parameters appear in your function.
# For example, for the `shmmodel` above, the initial guess could be defined as below.</p>

# %%
## Make a list of the initial guess parameters for curve_fit(shmmodel, ..., p0=params_init)
params_init = [S0guess, A0guess, omegaguess, phiguess]

# %% [markdown]
# <p style="color: blue">If you are having trouble with the fit, it can be helpful to plot the function with your initial guess on the same plots as your data.</p>

# %% [markdown]
# <p style="color: blue">**Fit your damped harmonic oscillator function to each of the data sets.
# Print the values of the best-fit parameters and their standard deviations.
# Make a plot of the best-fit functions superposed on the data sets.**</p>

# %% [markdown]
# ## Part 3:  Estimate $G$!

# %% [markdown]
# <p style="color: blue">Although it will take a bit of algebra, all that is required to estimate $G$ are the results of these two fits and the following data about the experimental apparatus:</p>
#
# - <div style="color: blue">Mass of the two large masses, $M = 1.493 \pm 0.002\,\mathrm{kg}$ each,</div>
# - <div style="color: blue">Length of the pendulum arms, $r = 0.0500 \pm 0.0001\,\mathrm{m}$,</div>
# - <div style="color: blue">Distance between the centers of the small and large lead balls, $b = 0.042 \pm 0.001\,\mathrm{m}$,</div>
# - <div style="color: blue">Distance from the mirror to the screen, $L = 2.265 \pm 0.010\,\mathrm{m}$.</div>
#
# <p style="color: blue">The values of ther quantities, such as $m$ or $\kappa$, cancel in the final result or can be estimated from the fit.</p>

# %% [markdown]
# ### <a name="P3.1">3.1</a>
#
# <p style="color: blue">Write the equation for the balancing of torques due to gravity and to the wire torsion (see [Pre-lab 2](#Prelab2)).
# Invert this to obtain a relation for $G$ in terms of the masses $m$ and $M$, the distance between the spheres $b$, the torsion constant $\kappa$, the length of the pendulum arms $r$, and the twist angle $\theta_i$.</p>

# %% [markdown]
# ### <a name="P3.2">3.2</a>
#
# <p style="color: blue">From the fits, we can obtain estimates for the distance $S_i$ between the position of laser dot at equilibrium angle $\theta_i$ and at the untwisted position.
# We also have estimates of the angular frequence $\omega_0 \equiv \sqrt{\kappa / I}$.
# Use [Eq. 13](#eq:stan) and the expression for $\omega_0$ to eliminate $\kappa$ and $\theta_i$ from the relation for $G$.
# Finally, use [Eq. 6](#eq:moment) to eliminate $I$.</p>

# %% [markdown]
# <p style="color: blue"><a name="eq:end">*Equation 15:*</a>  Hopefully, the result is something like this
# \begin{equation}
#   G = \frac{b^2 r\,\omega_0^2 S_i}{2\,L\,M}
# \end{equation}</p>

# %% [markdown]
# ### <a name="P3.3">3.3</a>
#
# <p style="color: blue">Finally, consider how to interpret and combine the results from the two data sets.</p>
#
# <p style="color: blue">The torsion pendulum itself did not change between the two data sets, so the two estimated values for $\omega_0$ are expected to be the same.
# If they are not the same within their estimated uncertainties, that could indicate that the analysis is underestimating the uncertainty.
# It could also indicate some unexpected and unknown variation in the experimental conditions.
# *What is the best value of $\omega_0$ to use in the calculation of $G$?*</p>

# %% [markdown]
# <p style="color: blue">The position of the laser spot when the large masses are abesent was never measured.
# *Given the symmetry of setup for the two data sets, how can the equilibrium positions $S_1$ and $S_2$ be used to determine the untwisted position of the laser spot?*</p>

# %% [markdown]
# <p style="color: blue">With these considerations in mind, estimate $G$!
# Compare the result to the prevailing value.
# If time permits, use standard error propagation to obtain an uncertainty for the result.</p>

# %% [markdown]
# <p style="color: blue">It should be noted that, although we will not go into them here, there are some further refinements that could be made to the analysis that can improve the estimate even with this data set.</p>
